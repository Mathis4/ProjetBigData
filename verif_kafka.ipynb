# %%
from kafka import KafkaConsumer
import json

# Variables de configuration
KAFKA_TOPIC = "github_repos"
KAFKA_BOOTSTRAP_SERVERS = "localhost:9092"

# Initialisation du consommateur Kafka
consumer = KafkaConsumer(
    KAFKA_TOPIC,
    bootstrap_servers=KAFKA_BOOTSTRAP_SERVERS,
    group_id="github_repos_consumer_group",  # Groupe de consommateurs
    value_deserializer=lambda x: json.loads(x.decode('utf-8'))  # Désérialisation du message en JSON
)

# Fonction pour afficher les données des dépôts
def display_repos_from_kafka():
    print("En attente de nouveaux messages sur Kafka...")
    for message in consumer:
        repo_data = message.value  # Contenu du message Kafka (les données du dépôt)
        
        # Affichage des informations du dépôt
        repo_name = repo_data.get('repo_name', 'Nom inconnu')
        html_url = repo_data.get('html_url', 'URL non disponible')
        description = repo_data.get('description', 'Pas de description')
        created_at = repo_data.get('created_at', 'Date inconnue')
        topics = repo_data.get('topics', [])
        
        # Affichage avec gestion des topics et des descriptions
        print(f"Nom du dépôt: {repo_name}")
        print(f"URL du dépôt: {html_url}")
        print(f"Description: {description if description else 'Pas de description disponible'}")
        print(f"Date de création: {created_at}")
        
        # Affichage des topics
        if topics:
            print(f"Topics: {', '.join(topics)}")
        else:
            print("Topics: Aucun topic")
        
        print("-" * 50)

if __name__ == "__main__":
    try:
        display_repos_from_kafka()  # Consommer et afficher les messages
    except KeyboardInterrupt:
        print("Arrêt du consommateur Kafka.")
    finally:
        consumer.close()
# Out:
# En attente de nouveaux messages sur Kafka...
# Nom du dépôt: DeepSeek-R1
# URL du dépôt: https://github.com/deepseek-ai/DeepSeek-R1
# Description: Pas de description disponible
# Date de création: 2025-01-20T11:57:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: open-r1
# URL du dépôt: https://github.com/huggingface/open-r1
# Description: Fully open reproduction of DeepSeek-R1
# Date de création: 2025-01-24T15:44:11Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: TinyZero
# URL du dépôt: https://github.com/Jiayi-Pan/TinyZero
# Description: Clean, minimal, accessible reproduction of DeepSeek R1-Zero
# Date de création: 2025-01-21T16:49:12Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Hunyuan3D-2
# URL du dépôt: https://github.com/Tencent/Hunyuan3D-2
# Description: High-Resolution 3D Assets Generation with Large Scale Hunyuan3D Diffusion Models.
# Date de création: 2025-01-21T05:21:35Z
# Topics: 3d, 3d-aigc, 3d-generation, diffusion-models, hunyuan3d, image-to-3d, shape, shape-generation, text-to-3d, texture-generation
# --------------------------------------------------
# Nom du dépôt: web-ui
# URL du dépôt: https://github.com/browser-use/web-ui
# Description: Run AI Agent in your browser.
# Date de création: 2025-01-02T01:29:44Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: openai-realtime-agents
# URL du dépôt: https://github.com/openai/openai-realtime-agents
# Description: This is a simple demonstration of more advanced, agentic patterns built on top of the Realtime API.
# Date de création: 2025-01-16T01:29:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: pebble
# URL du dépôt: https://github.com/google/pebble
# Description: This is the latest version of the internal repository from Pebble Technology providing the software to run on Pebble watches. Proprietary source code has been removed from this repository and it will not compile as-is. This is for information only.
# Date de création: 2025-01-21T21:11:59Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: stripe-recommendations
# URL du dépôt: https://github.com/t3dotgg/stripe-recommendations
# Description: I've built with Stripe for years. This is how I do it without going mad.
# Date de création: 2025-01-11T06:44:42Z
# Topics: fullstack, nextjs, node, payments, stripe, typescript
# --------------------------------------------------
# Nom du dépôt: MikuMikuBeam
# URL du dépôt: https://github.com/sammwyy/MikuMikuBeam
# Description: An open-source network stresser tool but it's Hatsune Miku
# Date de création: 2025-01-20T02:45:30Z
# Topics: ddos, ddos-attack-tools, ddos-attacks, ddos-tool, ddoser, hatsune-miku, miku, stresses
# --------------------------------------------------
# Nom du dépôt: AgentLaboratory
# URL du dépôt: https://github.com/SamuelSchmidgall/AgentLaboratory
# Description: Agent Laboratory is an end-to-end autonomous research workflow meant to assist you as the human researcher toward implementing your research ideas
# Date de création: 2025-01-08T02:00:51Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: YuE
# URL du dépôt: https://github.com/multimodal-art-projection/YuE
# Description: YuE: Open Full-song Music Generation Foundation Model, something similar to Suno.ai but open
# Date de création: 2025-01-23T06:21:58Z
# Topics: agi, ai, artificial-intelligence, deep-learning, foundation-models, gpt, huggingface, llama, llm, music-generation, style-transfer, voice-cloning
# --------------------------------------------------
# Nom du dépôt: AI-Crash-Course
# URL du dépôt: https://github.com/henrythe9th/AI-Crash-Course
# Description: AI Crash Course to help busy builders catch up to the public frontier of AI research in 2 weeks
# Date de création: 2025-01-08T05:43:56Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Kimi-k1.5
# URL du dépôt: https://github.com/MoonshotAI/Kimi-k1.5
# Description: Pas de description disponible
# Date de création: 2025-01-19T15:42:57Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Riona-AI-Agent
# URL du dépôt: https://github.com/David-patrick-chuks/Riona-AI-Agent
# Description: Riona 🌸 is built with Node.js and TypeScript 🛠️. Designed to run jobs 📸 effortlessly. Lightweight, efficient, and a work in progress 🚧—more features coming soon! 🌟
# Date de création: 2025-01-11T05:45:37Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: SkyThought
# URL du dépôt: https://github.com/NovaSky-AI/SkyThought
# Description: Sky-T1: Train your own O1 preview model within $450
# Date de création: 2025-01-09T21:37:37Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: UI-TARS-desktop
# URL du dépôt: https://github.com/bytedance/UI-TARS-desktop
# Description: A GUI Agent application based on UI-TARS(Vision-Lanuage Model) that allows you to control your computer using natural language.
# Date de création: 2025-01-19T09:04:43Z
# Topics: agent, browser-use, computer-use, electron, gui-agents, vision, vite, vlm
# --------------------------------------------------
# Nom du dépôt: perforator
# URL du dépôt: https://github.com/yandex/perforator
# Description: Perforator is a cluster-wide continuous profiling tool designed for large data centers
# Date de création: 2025-01-29T14:20:43Z
# Topics: continuous-profiling, ebpf, flamegraph, performance, performance-tools, profiling
# --------------------------------------------------
# Nom du dépôt: MiniMax-01
# URL du dépôt: https://github.com/MiniMax-AI/MiniMax-01
# Description: Pas de description disponible
# Date de création: 2025-01-14T15:43:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: UI-TARS
# URL du dépôt: https://github.com/bytedance/UI-TARS
# Description: Pas de description disponible
# Date de création: 2025-01-19T09:04:17Z
# Topics: research
# --------------------------------------------------
# Nom du dépôt: Gemini-Search
# URL du dépôt: https://github.com/ammaarreshi/Gemini-Search
# Description: Perplexity style AI Search engine clone built with Gemini 2.0 Flash and Grounding
# Date de création: 2025-01-04T14:07:19Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: simpleRL-reason
# URL du dépôt: https://github.com/hkust-nlp/simpleRL-reason
# Description: This is a replicate of DeepSeek-R1-Zero and DeepSeek-R1 training on small models with limited data
# Date de création: 2025-01-25T07:16:58Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: self-consistent-coder
# URL du dépôt: https://github.com/zhangchenchen/self-consistent-coder
# Description: 如何成为一名自洽的程序员
# Date de création: 2025-01-09T06:49:53Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: deepclaude
# URL du dépôt: https://github.com/getAsterisk/deepclaude
# Description: A high-performance LLM inference API and Chat UI that integrates DeepSeek R1's CoT reasoning traces with Anthropic Claude models.
# Date de création: 2025-01-26T16:25:41Z
# Topics: ai, anthropic, anthropic-claude, api, chain-of-thought, claude, deepseek, deepseek-r1, llm, rust
# --------------------------------------------------
# Nom du dépôt: Bricklayers
# URL du dépôt: https://github.com/TengerTechnologies/Bricklayers
# Description: A processing script for Bricklayers in Prusaslicer and Orcaslicer
# Date de création: 2025-01-22T18:13:43Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: executive-ai-assistant
# URL du dépôt: https://github.com/langchain-ai/executive-ai-assistant
# Description: Pas de description disponible
# Date de création: 2025-01-14T06:17:25Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: yek
# URL du dépôt: https://github.com/bodo-run/yek
# Description: A fast Rust based tool to serialize text-based files in a repository or directory for LLM consumption
# Date de création: 2025-01-11T16:35:26Z
# Topics: ai, cli, large-language-models, llm, rust-lang, serialization
# --------------------------------------------------
# Nom du dépôt: cs16.css
# URL du dépôt: https://github.com/ekmas/cs16.css
# Description: CSS library based on Counter Strike 1.6 UI.
# Date de création: 2025-01-22T14:36:59Z
# Topics: counter-strike, cs-16, cs16, css-library, retro, retro-ui
# --------------------------------------------------
# Nom du dépôt: kokoro-onnx
# URL du dépôt: https://github.com/thewh1teagle/kokoro-onnx
# Description: TTS with kokoro and onnx runtime
# Date de création: 2025-01-03T14:59:41Z
# Topics: kokoro, onnxruntime, python, tts
# --------------------------------------------------
# Nom du dépôt: Nrfr
# URL du dépôt: https://github.com/Ackites/Nrfr
# Description: 🌍 免 Root 的 SIM 卡国家码修改工具 | 解决国际漫游时的兼容性问题，帮助使用海外 SIM 卡获得更好的本地化体验，解锁运营商限制，突破区域限制
# Date de création: 2025-01-01T05:57:30Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: swift-build
# URL du dépôt: https://github.com/swiftlang/swift-build
# Description: A high-level build system based on llbuild, used by Xcode, Swift Playground, and the Swift Package Manager
# Date de création: 2025-01-28T18:53:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: audiblez
# URL du dépôt: https://github.com/santinic/audiblez
# Description: Generate audiobooks from e-books
# Date de création: 2025-01-14T14:36:20Z
# Topics: audiobooks, epub, kokoro, python, tts
# --------------------------------------------------
# Nom du dépôt: go-haystack
# URL du dépôt: https://github.com/hybridgroup/go-haystack
# Description: Track personal Bluetooth devices via Apple's "Find My" network using OpenHaystack and Macless-Haystack with tools written in Go/TinyGo. No Apple hardware required!
# Date de création: 2025-01-09T13:40:45Z
# Topics: airtag, bluetooth, find-my, findmy, golang, openhaystack, tinygo
# --------------------------------------------------
# Nom du dépôt: linuxpdf
# URL du dépôt: https://github.com/ading2210/linuxpdf
# Description: Linux running inside a PDF file via a RISC-V emulator
# Date de création: 2025-01-14T19:36:42Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: moon-dev-ai-agents
# URL du dépôt: https://github.com/moondevonyt/moon-dev-ai-agents
# Description: autonomous open source ai agents in python
# Date de création: 2025-01-01T13:33:16Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: khi
# URL du dépôt: https://github.com/GoogleCloudPlatform/khi
# Description: A transformative log viewer for Kubernetes
# Date de création: 2025-01-22T01:58:02Z
# Topics: google-cloud-platform, kubernetes, observability, visualizer
# --------------------------------------------------
# Nom du dépôt: NeuralSVG
# URL du dépôt: https://github.com/SagiPolaczek/NeuralSVG
# Description: Official implementation of NerualSVG
# Date de création: 2025-01-07T09:15:42Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: smolGPT
# URL du dépôt: https://github.com/Om-Alve/smolGPT
# Description: Pas de description disponible
# Date de création: 2025-01-12T14:49:21Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: isd
# URL du dépôt: https://github.com/isd-project/isd
# Description: isd (interactive systemd) – a better way to work with systemd units
# Date de création: 2025-01-16T19:37:15Z
# Topics: cli, systemctl, systemd, textual, tui
# --------------------------------------------------
# Nom du dépôt: documentdb
# URL du dépôt: https://github.com/microsoft/documentdb
# Description: DocumentDB offers a native implementation of document-oriented NoSQL database, enabling seamless CRUD operations on BSON data types within a PostgreSQL framework. Powering vCore-based Azure Cosmos DB for MongoDB.
# Date de création: 2025-01-22T19:59:22Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Pollens
# URL du dépôt: https://github.com/PollensAI/Pollens
# Description: Buzz Together in Real Time: Your BeeSync for Collaborative Creation and Connection.
# Date de création: 2025-01-09T13:43:01Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: open-operator
# URL du dépôt: https://github.com/browserbase/open-operator
# Description: Pas de description disponible
# Date de création: 2025-01-23T23:36:18Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: titans-pytorch
# URL du dépôt: https://github.com/lucidrains/titans-pytorch
# Description: Unofficial implementation of Titans, SOTA memory for transformers, in Pytorch
# Date de création: 2025-01-08T15:26:27Z
# Topics: artificial-intelligence, deep-learning, long-term-memory, test-time-training
# --------------------------------------------------
# Nom du dépôt: pdftris
# URL du dépôt: https://github.com/ThomasRinsma/pdftris
# Description: Pas de description disponible
# Date de création: 2025-01-04T22:17:33Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: node-DeepResearch
# URL du dépôt: https://github.com/jina-ai/node-DeepResearch
# Description: Keep searching and reading webpages until finding the answer (or exceeding the token budget).
# Date de création: 2025-01-26T06:46:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: always-on-ai-assistant
# URL du dépôt: https://github.com/disler/always-on-ai-assistant
# Description: A pattern for an always on AI Assistant powered by Deepseek-V3, RealtimeSTT, and Typer for engineering
# Date de création: 2025-01-12T18:17:51Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: deepseek_project
# URL du dépôt: https://github.com/1692775560/deepseek_project
# Description: Dee-seek_project
# Date de création: 2025-01-27T02:54:10Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Dither3D
# URL du dépôt: https://github.com/runevision/Dither3D
# Description: Surface-Stable Fractal Dithering
# Date de création: 2025-01-23T15:08:31Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Sa2VA
# URL du dépôt: https://github.com/magic-research/Sa2VA
# Description: 🔥 Sa2VA: Marrying SAM2 with LLaVA for Dense Grounded Understanding of Images and Videos
# Date de création: 2025-01-06T15:03:53Z
# Topics: computer-vision, mllm
# --------------------------------------------------
# Nom du dépôt: rag-web-ui
# URL du dépôt: https://github.com/rag-web-ui/rag-web-ui
# Description: RAG Web UI is an intelligent dialogue system based on RAG (Retrieval-Augmented Generation) technology.
# Date de création: 2025-01-14T01:48:30Z
# Topics: ai, langchain, rag
# --------------------------------------------------
# Nom du dépôt: coconut
# URL du dépôt: https://github.com/facebookresearch/coconut
# Description: Training Large Language Model to Reason in a Continuous Latent Space
# Date de création: 2025-01-15T05:43:45Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: DeepRant
# URL du dépôt: https://github.com/liseami/DeepRant
# Description: -游戏文字交流AI嘴强王者工具
# Date de création: 2025-01-30T07:28:25Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: curso-python
# URL du dépôt: https://github.com/midudev/curso-python
# Description: Curso de Python desde cero y para todos los públicos con ejercicios
# Date de création: 2025-01-15T08:31:27Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: BrowserAI
# URL du dépôt: https://github.com/Cloud-Code-AI/BrowserAI
# Description: Run local LLMs inside your browser
# Date de création: 2025-01-08T00:26:51Z
# Topics: agents, ai, llm, llm-inference, localllm, tts, webgpu
# --------------------------------------------------
# Nom du dépôt: termora
# URL du dépôt: https://github.com/TermoraDev/termora
# Description: Termora is a terminal emulator and SSH client for Windows, macOS and Linux.
# Date de création: 2025-01-02T02:41:09Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: one-small-step
# URL du dépôt: https://github.com/karminski/one-small-step
# Description: 这是一个简单的技术科普教程项目，主要聚焦于解释一些有趣的，前沿的技术概念和原理。每篇文章都力求在 5 分钟内阅读完成。
# Date de création: 2025-01-16T01:32:15Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: awesome-launch
# URL du dépôt: https://github.com/KingMenes/awesome-launch
# Description: A directory for free and friendly communities to get eyes on your side projects! Contributors are welcome!
# Date de création: 2025-01-13T19:44:31Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: MatchAnything
# URL du dépôt: https://github.com/zju3dv/MatchAnything
# Description: Code for "MatchAnything: Universal Cross-Modality Image Matching with Large-Scale Pre-Training", Arxiv 2025.
# Date de création: 2025-01-09T12:51:24Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: composecraft
# URL du dépôt: https://github.com/composecraft/composecraft
# Description: Pas de description disponible
# Date de création: 2025-01-02T00:18:31Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Go-with-the-Flow
# URL du dépôt: https://github.com/Eyeline-Research/Go-with-the-Flow
# Description: Motion-Controllable Video Diffusion via Warped Noise
# Date de création: 2025-01-09T05:26:11Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: acu
# URL du dépôt: https://github.com/francedot/acu
# Description: A curated list of resources about AI agents for Computer Use, including research papers, projects, frameworks, and tools.
# Date de création: 2025-01-05T15:56:34Z
# Topics: ai, ai-research, awesome, computer, computer-use, gui-agent, ui-agent
# --------------------------------------------------
# Nom du dépôt: sitefetch
# URL du dépôt: https://github.com/egoist/sitefetch
# Description: Fetch an entire site and save it as a text file (to be used with AI models).
# Date de création: 2025-01-07T08:43:01Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: RAGEN
# URL du dépôt: https://github.com/ZihanWang314/RAGEN
# Description: RAGEN is the first open-source reproduction of DeepSeek-R1 for training agentic models via reinforcement learning.
# Date de création: 2025-01-25T19:31:40Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Math-To-Manim
# URL du dépôt: https://github.com/HarleyCoops/Math-To-Manim
# Description: Pas de description disponible
# Date de création: 2025-01-20T11:04:50Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: llm-api-engine
# URL du dépôt: https://github.com/developersdigest/llm-api-engine
# Description: Build and deploy AI-powered APIs in seconds
# Date de création: 2025-01-24T16:08:47Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: fancy_job
# URL du dépôt: https://github.com/Shogun89/fancy_job
# Description: Have you ever wanted a fancy job? This repo gets you a fancy job! /s
# Date de création: 2025-01-01T19:44:55Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: dev-dapp-season1
# URL du dépôt: https://github.com/rairprotocol/dev-dapp-season1
# Description: Learn how to deploy open-source Dapps while participating in our incentives program
# Date de création: 2025-01-06T20:10:48Z
# Topics: akash, devops, devops-platform, devops-tools, docker, mongodb, web3
# --------------------------------------------------
# Nom du dépôt: Prismui
# URL du dépôt: https://github.com/Codehagen/Prismui
# Description: A fully customizable component library built on top of shadcn/ui. Beautiful, accessible, and ready for production.
# Date de création: 2025-01-03T08:53:54Z
# Topics: open-source, prisma, shadcn-ui, tailwind, typescript
# --------------------------------------------------
# Nom du dépôt: uscope
# URL du dépôt: https://github.com/jcalabro/uscope
# Description: μscope 🔬
# Date de création: 2025-01-01T13:46:52Z
# Topics: debugger, developer-tools, introspection, linux, zig
# --------------------------------------------------
# Nom du dépôt: wordpecker-app
# URL du dépôt: https://github.com/baturyilmaz/wordpecker-app
# Description:  A personalized language-learning tool that combines Duolingo-style lessons with your own curated vocabulary lists. Seamlessly add words from books, articles, or videos, and revisit them through interactive quizzes and LLM-generated lessons.
# Date de création: 2025-01-20T12:26:43Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: RAT-retrieval-augmented-thinking
# URL du dépôt: https://github.com/Doriandarko/RAT-retrieval-augmented-thinking
# Description: RAT is a powerful tool that improves AI responses by leveraging DeepSeek's reasoning capabilities to guide other models through a structured thinking process.
# Date de création: 2025-01-23T19:00:55Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: KernelSU-Next
# URL du dépôt: https://github.com/rifsxd/KernelSU-Next
# Description: A Kernel based root solution for Android
# Date de création: 2025-01-11T08:30:02Z
# Topics: android, kernel, kernelsu, kernelsu-next, root, su
# --------------------------------------------------
# Nom du dépôt: MiniRAG
# URL du dépôt: https://github.com/HKUDS/MiniRAG
# Description: "MiniRAG: Making RAG Simpler with Small and Free Language Models"
# Date de création: 2025-01-11T13:24:14Z
# Topics: large-language-models, rag, retrieval-augmented-generation
# --------------------------------------------------
# Nom du dépôt: exa-deepseek-chat
# URL du dépôt: https://github.com/exa-labs/exa-deepseek-chat
# Description: A simple open-source chat app that uses Exa's API for web search and Deepseek R1 for reasoning
# Date de création: 2025-01-28T15:14:03Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Search-o1
# URL du dépôt: https://github.com/sunnynexus/Search-o1
# Description: Search-o1: Agentic Search-Enhanced Large Reasoning Models
# Date de création: 2025-01-03T15:37:43Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: magnetron
# URL du dépôt: https://github.com/MarioSieg/magnetron
# Description: (WIP) A small but powerful, homemade PyTorch from scratch.
# Date de création: 2025-01-02T21:25:56Z
# Topics: artificial-intelligence, cpp, cuda, high-performance-computing, machine-learning, neuronal-network, python, pytorch, research-project, tensorflow, tiny
# --------------------------------------------------
# Nom du dépôt: LabStack
# URL du dépôt: https://github.com/JaredC01/LabStack
# Description: Modular rackmount solutions for Raspberry Pi's and other SBC's and accessories.
# Date de création: 2025-01-17T02:26:00Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: AI-Resources-Central
# URL du dépôt: https://github.com/CoderSJX/AI-Resources-Central
# Description:  Bringing together outstanding artificial intelligence (AI) open source projects from around the world.
# Date de création: 2025-01-08T01:44:10Z
# Topics: agent, ai, chatgpt, functioncall, gemini, llm, machine-learning, model, ollama, openai, prompt-engineering, qwen, spring-ai, transformer
# --------------------------------------------------
# Nom du dépôt: BadWebsiteBlocklist
# URL du dépôt: https://github.com/popcar2/BadWebsiteBlocklist
# Description: A filter that blocks spam & misleading websites from appearing in search results via uBlocklist
# Date de création: 2025-01-06T11:57:03Z
# Topics: blacklist, blocklist, search-engine
# --------------------------------------------------
# Nom du dépôt: free-ai-money-printer
# URL du dépôt: https://github.com/FractalXBT/free-ai-money-printer
# Description: Pas de description disponible
# Date de création: 2025-01-30T09:30:36Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: open-thoughts
# URL du dépôt: https://github.com/open-thoughts/open-thoughts
# Description: Open Thoughts: Fully Open Data Curation for Thinking Models
# Date de création: 2025-01-27T22:28:56Z
# Topics: open-data, reasoning
# --------------------------------------------------
# Nom du dépôt: A_Share_investment_Agent
# URL du dépôt: https://github.com/24mlight/A_Share_investment_Agent
# Description: Pas de description disponible
# Date de création: 2025-01-07T06:56:46Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: PPTAgent
# URL du dépôt: https://github.com/icip-cas/PPTAgent
# Description: PPTAgent: Generating and Evaluating Presentations Beyond Text-to-Slides
# Date de création: 2025-01-04T00:54:29Z
# Topics: agent, llm, nlp, powerpoint
# --------------------------------------------------
# Nom du dépôt: desktopmate-custom-avatar-loader
# URL du dépôt: https://github.com/YusufOzmen01/desktopmate-custom-avatar-loader
# Description: Custom Avatar Loader Mod for DesktopMate!
# Date de création: 2025-01-09T19:42:19Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: any-listen
# URL du dépôt: https://github.com/any-listen/any-listen
# Description: A cross-platform private song playback service.
# Date de création: 2025-01-26T07:49:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: WinVisor
# URL du dépôt: https://github.com/x86matthew/WinVisor
# Description: WinVisor - A hypervisor-based emulator for Windows x64 user-mode executables using Windows Hypervisor Platform API
# Date de création: 2025-01-22T22:47:35Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Video-Depth-Anything
# URL du dépôt: https://github.com/DepthAnything/Video-Depth-Anything
# Description: Video Depth Anything: Consistent Depth Estimation for Super-Long Videos
# Date de création: 2025-01-21T12:38:10Z
# Topics: depth-estimation, monocular-depth-estimation, transformer, video-depth
# --------------------------------------------------
# Nom du dépôt: pippin
# URL du dépôt: https://github.com/pippinlovesyou/pippin
# Description: The Digital Being Framework for Autonomous Agents
# Date de création: 2025-01-09T15:21:37Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: CVE-2024-49113
# URL du dépôt: https://github.com/SafeBreach-Labs/CVE-2024-49113
# Description: LdapNightmare is a PoC tool that tests a vulnerable Windows Server against CVE-2024-49113
# Date de création: 2025-01-01T15:48:38Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Decky-Framegen
# URL du dépôt: https://github.com/xXJSONDeruloXx/Decky-Framegen
# Description: Steam Deck Plugin to apply Framegen mods to games by replacing DLSS DLL with FSR3 DLL
# Date de création: 2025-01-21T23:52:49Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: llama.vscode
# URL du dépôt: https://github.com/ggml-org/llama.vscode
# Description: VS Code extension for local LLM-assisted code/text completion
# Date de création: 2025-01-06T11:54:52Z
# Topics: copilot, developer-tool, extension, llama, llm, vscode
# --------------------------------------------------
# Nom du dépôt: Cuda-120-Days-Challenge
# URL du dépôt: https://github.com/AdepojuJeremy/Cuda-120-Days-Challenge
# Description: A 120-day CUDA learning plan covering daily concepts, exercises, pitfalls, and references (including “Programming Massively Parallel Processors”). Features six capstone projects to solidify GPU parallel programming, memory management, and performance optimization skills.
# Date de création: 2025-01-23T19:57:33Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: kokoro
# URL du dépôt: https://github.com/hexgrad/kokoro
# Description: https://hf.co/hexgrad/Kokoro-82M
# Date de création: 2025-01-10T21:37:05Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: com.xchat
# URL du dépôt: https://github.com/Xposed-Modules-Repo/com.xchat
# Description: XChat
# Date de création: 2025-01-04T20:31:33Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: thinking-gemini
# URL du dépôt: https://github.com/lanesky/thinking-gemini
# Description: Pas de description disponible
# Date de création: 2025-01-05T00:15:57Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: WebRover
# URL du dépôt: https://github.com/hrithikkoduri/WebRover
# Description: WebRover is an autonomous AI agent designed to interpret user input and execute actions by interacting with web elements to accomplish tasks or answer questions. It leverages advanced language models and web automation tools to navigate the web, gather information, and provide structured responses based on the user's needs.
# Date de création: 2025-01-14T01:11:21Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: llmpeg
# URL du dépôt: https://github.com/jjcm/llmpeg
# Description: Uses an llm to generate ffmpeg commands
# Date de création: 2025-01-15T01:44:26Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: cursor-deepseek
# URL du dépôt: https://github.com/danilofalcao/cursor-deepseek
# Description: A high-performance HTTP/2-enabled proxy server designed specifically to enable Cursor IDE's Composer to use DeepSeek's and OpenRouter's language models. This proxy translates OpenAI-compatible API requests to DeepSeek/OpenRouter API format, allowing Cursor's Composer and other OpenAI API-compatible tools to seamlessly work with these models.
# Date de création: 2025-01-21T21:56:17Z
# Topics: cursor, deepseek, openrouter
# --------------------------------------------------
# Nom du dépôt: gemini-playground
# URL du dépôt: https://github.com/tech-shrimp/gemini-playground
# Description: Deploy a Gemini multimodal chat website in 10 seconds, Severless!         只需准备一个Gemini API Key，10秒即可部署一个Gemini多模态对话的网站。
# Date de création: 2025-01-03T10:13:57Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: DiffusionAsShader
# URL du dépôt: https://github.com/IGL-HKUST/DiffusionAsShader
# Description: [arXiv 2025] Diffusion as Shader: 3D-aware Video Diffusion for Versatile Video Generation Control
# Date de création: 2025-01-07T14:33:49Z
# Topics: 3d-generation, camera-control, motion-retargeting, motion-transfer, object-manipulation, video-generation
# --------------------------------------------------
# Nom du dépôt: Swox
# URL du dépôt: https://github.com/SwoxApp/Swox
# Description: About We are the next generation social network in the WEB3
# Date de création: 2025-01-16T21:47:01Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: jarvis
# URL du dépôt: https://github.com/danilofalcao/jarvis
# Description: J.A.R.V.I.S. is an intelligent coding assistant that leverages multiple state-of-the-art language models to help you with code generation, modifications, and technical discussions.
# Date de création: 2025-01-03T03:09:53Z
# Topics: assistant, coding
# --------------------------------------------------
# Nom du dépôt: Awesome-Object-Insertion
# URL du dépôt: https://github.com/bcmi/Awesome-Object-Insertion
# Description: A curated list of papers, code and resources pertaining to image composition/compositing or object insertion/addition/compositing, which aims to generate realistic composite image.
# Date de création: 2025-01-06T09:22:55Z
# Topics: image-compositing, image-composition, object-addition, object-compositing, object-insertion
# --------------------------------------------------
# Nom du dépôt: caddy-waf
# URL du dépôt: https://github.com/fabriziosalmi/caddy-waf
# Description: Caddy WAF (Regex Rules, IP and DNS filtering, Rate Limiting, GeoIP, Tor, Anomaly Detection)
# Date de création: 2025-01-02T12:13:56Z
# Topics: caddy, caddy-module, caddy-plugin, caddy-security, caddyserver, dns-blacklist, dns-filtering, geo-blocking, geoip2, ip-blacklist, ip-filtering, owasp, rate-limiter, rate-limiting, security-tools, waf, web-application-firewall, web-security
# --------------------------------------------------
# Nom du dépôt: backend-api-kit
# URL du dépôt: https://github.com/Dhravya/backend-api-kit
# Description: Easily create scalable, monetisable backend APIs with Hono + Cloudflare workers. All the batteries included.
# Date de création: 2025-01-24T22:20:16Z
# Topics: better-auth, cloudflare-d1, cloudflare-workers, drizzle-orm, hono
# --------------------------------------------------
# Nom du dépôt: ComfyUI-LatentSyncWrapper
# URL du dépôt: https://github.com/ShmuelRonen/ComfyUI-LatentSyncWrapper
# Description: This node provides lip-sync capabilities in ComfyUI using ByteDance's LatentSync model. It allows you to synchronize video lips with audio input.
# Date de création: 2025-01-01T19:06:20Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: ComfyUI-TeaCache
# URL du dépôt: https://github.com/welltop-cn/ComfyUI-TeaCache
# Description: Pas de description disponible
# Date de création: 2025-01-07T08:59:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Quarm
# URL du dépôt: https://github.com/Quarm-AI/Quarm
# Description: An AI agent swarm framework built in Python
# Date de création: 2025-01-16T19:30:57Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: zotifarrr
# URL du dépôt: https://github.com/Xoconoch/zotifarrr
# Description: Pas de description disponible
# Date de création: 2025-01-24T01:56:25Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: linkook
# URL du dépôt: https://github.com/JackJuly/linkook
# Description: 🔍 An OSINT tool for discovering linked social accounts and associated emails across multiple platforms using a single username.
# Date de création: 2025-01-30T17:35:16Z
# Topics: footprint, information-gathering, osint, osint-python, osint-tool, pentest-tool, pentesting, sherlock, sherlock-alternative, username-checker, username-search
# --------------------------------------------------
# Nom du dépôt: CaddyGen
# URL du dépôt: https://github.com/DeanWard/CaddyGen
# Description: Simplify Caddy configs with SSL, proxies, file servers, security headers, compression & more.
# Date de création: 2025-01-07T15:00:34Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Roadmap-To-Learn-Agentic-AI
# URL du dépôt: https://github.com/krishnaik06/Roadmap-To-Learn-Agentic-AI
# Description: Pas de description disponible
# Date de création: 2025-01-22T04:46:29Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: reasoning-gym
# URL du dépôt: https://github.com/open-thought/reasoning-gym
# Description: procedural reasoning datasets
# Date de création: 2025-01-23T08:39:53Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: openai-realtime-solar-system
# URL du dépôt: https://github.com/openai/openai-realtime-solar-system
# Description: Demo showing how to use the OpenAI Realtime API to navigate a 3D scene via tool calling
# Date de création: 2025-01-13T18:11:13Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Open-Tax-System-Kit
# URL du dépôt: https://github.com/Chuqiao-Wang-tax/Open-Tax-System-Kit
# Description: Open-Tax is an AI-powered cloud platform transforming tax compliance through automated data integration, real-time anomaly detection, and multi-jurisdictional reconciliation.
# Date de création: 2025-01-15T13:58:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: node-modules-inspector
# URL du dépôt: https://github.com/antfu/node-modules-inspector
# Description: Interactive UI for local node modules inspection
# Date de création: 2025-01-16T07:40:07Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: are-we-esm
# URL du dépôt: https://github.com/antfu/are-we-esm
# Description: Are we fully ESM yet?
# Date de création: 2025-01-15T07:54:07Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: homelab-public
# URL du dépôt: https://github.com/mkuthan/homelab-public
# Description: Homelab infrastructure as a code (IaaC)
# Date de création: 2025-01-18T19:54:01Z
# Topics: ansible, homelab, iaac, self-hosted, terraform
# --------------------------------------------------
# Nom du dépôt: Kokoros
# URL du dépôt: https://github.com/lucasjinreal/Kokoros
# Description: 🔥🔥 Kokoro in Rust. https://huggingface.co/hexgrad/Kokoro-82M Insanely fast, realtime TTS with high quality you ever have.
# Date de création: 2025-01-12T10:32:49Z
# Topics: kokoro, kokoro-tts, tts
# --------------------------------------------------
# Nom du dépôt: deno-api-proxy
# URL du dépôt: https://github.com/tech-shrimp/deno-api-proxy
# Description: 使用Deno将大模型的API 代理到国内，解决地区受限问题 Use Deno to proxy Open AI, Claude, Groq and other APIs to mainland China, breaking geographical restrictions.
# Date de création: 2025-01-29T11:02:10Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: TriangleBin
# URL du dépôt: https://github.com/Swung0x48/TriangleBin
# Description: Pas de description disponible
# Date de création: 2025-01-02T05:28:49Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: docker-pull-tar
# URL du dépôt: https://github.com/topcss/docker-pull-tar
# Description: Pas de description disponible
# Date de création: 2025-01-14T09:59:25Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Free_US_Investment_Agent_System
# URL du dépôt: https://github.com/24mlight/Free_US_Investment_Agent_System
# Description: Pas de description disponible
# Date de création: 2025-01-24T10:14:27Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: yapsearch
# URL du dépôt: https://github.com/rbrown101010/yapsearch
# Description: Pas de description disponible
# Date de création: 2025-01-21T09:15:36Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: FramePainter
# URL du dépôt: https://github.com/YBYBZhang/FramePainter
# Description: [arXiv 2025] Official pytorch implementation of "FramePainter: Endowing Interactive Image Editing with  Video Diffusion Priors"
# Date de création: 2025-01-04T11:19:59Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: ClintonCAT
# URL du dépôt: https://github.com/WayneKeenan/ClintonCAT
# Description: Chrome Browser Extension for automatically searching Rossmann's Consumer Action Taskforce (CAT) articles for the current site being visited.
# Date de création: 2025-01-27T08:22:59Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: LLaVA-Mini
# URL du dépôt: https://github.com/ictnlp/LLaVA-Mini
# Description: LLaVA-Mini is a unified large multimodal model (LMM) that can support the understanding of images, high-resolution images, and videos in an efficient manner.
# Date de création: 2025-01-07T18:37:05Z
# Topics: efficient, gpt4o, gpt4v, large-language-models, large-multimodal-models, llama, llava, multimodal, multimodal-large-language-models, video, vision, vision-language-model, visual-instruction-tuning
# --------------------------------------------------
# Nom du dépôt: ComfyUI-Janus-Pro
# URL du dépôt: https://github.com/CY-CHENYUE/ComfyUI-Janus-Pro
# Description: ComfyUI nodes for Janus-Pro, a unified multimodal understanding and generation framework.
# Date de création: 2025-01-27T19:35:12Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: spotizerr
# URL du dépôt: https://github.com/Xoconoch/spotizerr
# Description: Spotify music downloader with a lossless twist, based on the deezspot library
# Date de création: 2025-01-25T14:19:32Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: university-library-jsm
# URL du dépôt: https://github.com/adrianhajdin/university-library-jsm
# Description: Learn to build a production-grade University Library Management System with industry-standard practices; from rate-limiting, DDoS protection, caching, optimizations, multi-media uploads, complex db queries, and advanced error handling to automated workflows with custom notifications.
# Date de création: 2025-01-06T11:25:40Z
# Topics: authjs, nextjs, upstash
# --------------------------------------------------
# Nom du dépôt: cursor-free-vip
# URL du dépôt: https://github.com/yeongpin/cursor-free-vip
# Description: （Multi Language 多语言）自动注册 Cursor Ai ，自动重置机器ID ， 免费升级使用Pro 功能: You've reached your trial request limit. / Too many free trial accounts used on this machine. Please upgrade to pro. We have this limit in place to prevent abuse. Please let us know if you believe this is a mistake.
# Date de création: 2025-01-11T08:14:22Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: r1-web
# URL du dépôt: https://github.com/sdan/r1-web
# Description: Pas de description disponible
# Date de création: 2025-01-29T11:53:52Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: agcplayer-widgets
# URL du dépôt: https://github.com/zoroyyoo/agcplayer-widgets
# Description: AGC Player 小组件
# Date de création: 2025-01-06T09:52:58Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: VideoLLaMA3
# URL du dépôt: https://github.com/DAMO-NLP-SG/VideoLLaMA3
# Description: Frontier Multimodal Foundation Models for Image and Video Understanding
# Date de création: 2025-01-19T11:06:53Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: cursorrules
# URL du dépôt: https://github.com/kinopeee/cursorrules
# Description: Pas de description disponible
# Date de création: 2025-01-16T06:30:23Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: WebWalker
# URL du dépôt: https://github.com/Alibaba-NLP/WebWalker
# Description: 🌐 WebWalker: Benchmarking LLMs in Web Traversal
# Date de création: 2025-01-09T11:07:35Z
# Topics: agent, alibaba, artificial-intelligence, information-seeking, llm, multi-agent, rag, web-agent
# --------------------------------------------------
# Nom du dépôt: T6
# URL du dépôt: https://github.com/tensorgi/T6
# Description: The official implementation of Tensor ProducT ATTenTion Transformer (T6)
# Date de création: 2025-01-10T19:30:12Z
# Topics: deep-learning, foundation-models, large-language-models, llms, model-architectures, pretraining
# --------------------------------------------------
# Nom du dépôt: open-r1-multimodal
# URL du dépôt: https://github.com/EvolvingLMMs-Lab/open-r1-multimodal
# Description: A fork to add multimodal model training to open-r1
# Date de création: 2025-01-27T09:41:10Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: caddy-defender
# URL du dépôt: https://github.com/JasonLovesDoggo/caddy-defender
# Description: Caddy module to block IPs and prevent AIs from training on your websites
# Date de création: 2025-01-14T22:55:23Z
# Topics: ai, ai-blocker, blocker, blockers, caddy, caddy-plugin, caddyserver, chatgpt, filter, ip-blacklist, ip-filtering, security, waf, web-security
# --------------------------------------------------
# Nom du dépôt: solana-raydium-sniper-bot
# URL du dépôt: https://github.com/lilmoat/solana-raydium-sniper-bot
# Description: The Solana Raydium Sniper Bot aims to catch new pools on Raydium and execute buy/sell transactions to make a profit. This Raydium sniper bot allows for manual and automated trading, giving users the flexibility to optimize their strategies and maximize returns.
# Date de création: 2025-01-21T19:28:47Z
# Topics: bot, jito-bundle, raydium, snipingbot, solana, trading
# --------------------------------------------------
# Nom du dépôt: react-movies
# URL du dépôt: https://github.com/adrianhajdin/react-movies
# Description: Dive straight into React—from basic JSX to advanced hooks—and build a real, modern app in this hands-on crash course!
# Date de création: 2025-01-24T13:38:19Z
# Topics: react19, reactjs, tailwindcss-v4
# --------------------------------------------------
# Nom du dépôt: cursor-pro-trial
# URL du dépôt: https://github.com/aigem/cursor-pro-trial
# Description: 安全又简便快捷地换标识码，for cursor pro trial。
# Date de création: 2025-01-04T15:29:30Z
# Topics: ai, cursor, free, trial, uuid
# --------------------------------------------------
# Nom du dépôt: X1a0HeWeChatPlugin
# URL du dépôt: https://github.com/X1a0He/X1a0HeWeChatPlugin
# Description: 一个随手写的微信插件，提供消息防撤回、显示红包转账详情、消息列表操作、头像圆角、毛玻璃模式、多开等功能
# Date de création: 2025-01-20T08:22:13Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: doom-docm
# URL du dépôt: https://github.com/wojciech-graj/doom-docm
# Description: DooM in Microsoft Word
# Date de création: 2025-01-18T03:29:28Z
# Topics: doom, microsoft, microsoft-word, source-port, word
# --------------------------------------------------
# Nom du dépôt: deepseek-laravel
# URL du dépôt: https://github.com/deepseek-php/deepseek-laravel
# Description: Laravel wrapper for Deepseek PHP client, to seamless deepseek API integration with laravel applications.
# Date de création: 2025-01-02T15:48:15Z
# Topics: chatgpt, deepseek-chat, deepseek-coder, deepseek-integration, deepseek-laravel, deepseek-math, deepseek-php, deepseek-php-client, deepseek-php-library, deepseek-r1, deepseek-r1-zero, laravel-ai, openai, openai-integration
# --------------------------------------------------
# Nom du dépôt: AI_NovelGenerator
# URL du dépôt: https://github.com/YILING0013/AI_NovelGenerator
# Description: 使用ai生成多章节的长篇小说，自动衔接上下文、伏笔
# Date de création: 2025-01-29T12:33:29Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: LLMs-Zero-to-Hero
# URL du dépôt: https://github.com/bbruceyuan/LLMs-Zero-to-Hero
# Description: 开个新坑，从无名小卒到大模型（LLM）大英雄~ 欢迎关注后续！！！
# Date de création: 2025-01-05T13:47:22Z
# Topics: llm, llm-from-zero-to-hero, llm-zero-to-hero, llm101
# --------------------------------------------------
# Nom du dépôt: hle
# URL du dépôt: https://github.com/centerforaisafety/hle
# Description: Humanity's Last Exam
# Date de création: 2025-01-23T00:10:21Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: AI-ContentCraft
# URL du dépôt: https://github.com/nicekate/AI-ContentCraft
# Description: AI ContentCraft is an all-in-one content creation suite that helps creators generate stories, podcast scripts, and multimedia content using AI-powered text generation, speech synthesis, and image generation capabilities.
# Date de création: 2025-01-19T02:35:13Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Image-Generation-CoT
# URL du dépôt: https://github.com/ZiyuGuo99/Image-Generation-CoT
# Description: Investigating CoT Reasoning in Autoregressive Image Generation
# Date de création: 2025-01-23T18:01:28Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: LLaSA_training
# URL du dépôt: https://github.com/zhenye234/LLaSA_training
# Description: LLaSA: Scaling Train-time and Test-time Compute for LLaMA-based Speech Synthesis
# Date de création: 2025-01-08T15:46:57Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: ClatScope
# URL du dépôt: https://github.com/Clats97/ClatScope
# Description: ClatScope Info Tool – The best and most versatile OSINT utility for retrieving geolocation, DNS, WHOIS, phone, email, data breach information and much more (35 features). Perfect for investigators, pentesters, or anyone looking for an effective reconnaissance / OSINT tool.
# Date de création: 2025-01-08T23:54:32Z
# Topics: intelligence, investigation, osint, osint-python, osint-reconnaissance, osint-resources, osint-tool, trending, trending-repositories
# --------------------------------------------------
# Nom du dépôt: baitroute
# URL du dépôt: https://github.com/utkusen/baitroute
# Description: A web honeypot library to create vulnerable-looking endpoints to detect and mislead attackers
# Date de création: 2025-01-14T13:03:07Z
# Topics: deception, decoy, honeypot, threat-analysis, threat-hunting, threat-intelligence
# --------------------------------------------------
# Nom du dépôt: tremor-blocks
# ...
# Description: The open-source security and compliance automation platform
# Date de création: 2025-01-07T17:15:37Z
# Topics: compliance, grc, soc2
# --------------------------------------------------
# Nom du dépôt: cewlai
# URL du dépôt: https://github.com/jthack/cewlai
# Description: ai-based domain name generation
# Date de création: 2025-01-18T04:24:11Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: KlutterTools
# URL du dépôt: https://github.com/keijiro/KlutterTools
# Description: Miscellaneous editor tools for Unity
# Date de création: 2025-01-01T13:18:43Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: local11labs
# URL du dépôt: https://github.com/nhaouari/local11labs
# Description: Local11Labs allows generating high-quality text-to-speech and podcast content using the fast and tiny Kokoro-82M.
# Date de création: 2025-01-03T13:31:11Z
# Topics: ai, generative, notebooklm, podcast, tts
# --------------------------------------------------
# Nom du dépôt: Godot-2D-Action-Game
# URL du dépôt: https://github.com/SakuyaCN/Godot-2D-Action-Game
# Description: Godot 2D Action Game
# Date de création: 2025-01-08T12:07:35Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: spyro-1
# URL du dépôt: https://github.com/TheMobyCollective/spyro-1
# Description: Spyro the Dragon Decompilation Project
# Date de création: 2025-01-23T21:55:50Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: macOS-config
# URL du dépôt: https://github.com/marsdevx/macOS-config
# Description: ⚙️ My configuration files for macOS ricing
# Date de création: 2025-01-10T08:08:07Z
# Topics: bash, config, customization, iterm2, loop, lua, macbook, macos, macos-config, macos-configuration, raycast, ricing, shell, shell-script, sketchybar, skhd, wallpaper, wallpapers, yabai, zsh
# --------------------------------------------------
# Nom du dépôt: AutoGenV04Test
# URL du dépôt: https://github.com/NanGePlus/AutoGenV04Test
# Description: AutoGen最新架构v0.4正式发布第一个稳定版本，v0.4是对AutoGen的一次从头开始的重写，目的是为构建Agent创建一个更健壮、可扩展、更易用的跨语言库，其应用接口采用分层架构设计，存在多套软件接口用以满足不同的场景需求 。
# Date de création: 2025-01-12T09:40:49Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Signal-Lens
# URL du dépôt: https://github.com/yannlemos/Signal-Lens
# Description: Plugin for Godot 4.3. Signal Lens allows you to visually debug a node's signal connections while testing your game.
# Date de création: 2025-01-09T00:24:47Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: DVBLab
# URL du dépôt: https://github.com/mamgad/DVBLab
# Description: This course uses a deliberately vulnerable banking application to demonstrate common security vulnerabilities, their impact, and how to fix them. The application is built with Flask (backend) and React (frontend).
# Date de création: 2025-01-03T23:05:54Z
# Topics: codereview, ctf, ctf-challenges, ctf-solutions, ctf-writeups, dvwa, educational-project, flask, hacking, pentest, python, security, webpentest, whitebox-testing
# --------------------------------------------------
# Nom du dépôt: scrstudio
# URL du dépôt: https://github.com/cvg/scrstudio
# Description: Pas de description disponible
# Date de création: 2025-01-02T09:08:02Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: react-native-css-animations
# URL du dépôt: https://github.com/software-mansion-labs/react-native-css-animations
# Description: React Native CSS Animation presets for Reanimated 4
# Date de création: 2025-01-15T09:08:16Z
# Topics: react-native, react-native-reanimated
# --------------------------------------------------
# Nom du dépôt: enhance
# URL du dépôt: https://github.com/addyosmani/enhance
# Description: Enhance and upscale your images using AI - right in your browser
# Date de création: 2025-01-02T23:47:04Z
# Topics: enhancement, image-processing, images, upscale, upscaler, upscalerimage
# --------------------------------------------------
# Nom du dépôt: project-argocd
# URL du dépôt: https://github.com/dellabeneta/project-argocd
# Description: Um projeto simples, mas completo, de implantação de um cluster K8S gerenciado, integrando Github Workflows, Docker e ArgoCD.
# Date de création: 2025-01-06T01:59:05Z
# Topics: argocd, ci, docker, github-actions, gitops, kubernetes, terraform
# --------------------------------------------------
# Nom du dépôt: ajj
# URL du dépôt: https://github.com/init4tech/ajj
# Description: A simple, modern, ergonomic JSON-RPC router, using tower and axum
# Date de création: 2025-01-08T19:30:00Z
# Topics: json-rpc, json-rpc-2, json-rpc-server, json-rpc2
# --------------------------------------------------
# Nom du dépôt: swiftui-theming
# URL du dépôt: https://github.com/alexanderwe/swiftui-theming
# Description: Effortless theming support in SwiftUI
# Date de création: 2025-01-05T09:38:54Z
# Topics: ios, macos, swiftui, theming, tvos, visionos, watchos
# --------------------------------------------------
# Nom du dépôt: AgentWeb3Tools
# URL du dépôt: https://github.com/KingJiongEN/AgentWeb3Tools
# Description: Enable Agents to conduct web3 operations, support wider applications for cross-chain bridging
# Date de création: 2025-01-10T07:23:57Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: reanimated-sparkles
# URL du dépôt: https://github.com/kacperkapusciak/reanimated-sparkles
# Description: Pas de description disponible
# Date de création: 2025-01-22T15:12:31Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: JJsploit
# URL du dépôt: https://github.com/ulvers909/JJsploit
# Description: JJSploit, now available for free, is a widely-used Roblox exploit favored for its simplicity and accessibility. With the ability to execute Lua scripts, it enables users to customize their gaming experience, though users should remain vigilant about potential risks associated with exploiting software.
# Date de création: 2025-01-30T13:10:52Z
# Topics: crack, exploiting, free, jjsploit, jjsploit-code-injector, jjsploit-custom-scripts, jjsploit-exploit-pack, jjsploit-game-modifier, jjsploit-mod-scripts, jjsploit-roblox-boost, jjsploit-roblox-bypass, jjsploit-roblox-enhance, jjsploit-roblox-enhancer, roblox
# --------------------------------------------------
# Nom du dépôt: Github-Agent
# URL du dépôt: https://github.com/LMSystems-ai/Github-Agent
# Description: Pas de description disponible
# Date de création: 2025-01-30T15:43:18Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: visimatch.nvim
# URL du dépôt: https://github.com/wurli/visimatch.nvim
# Description: A tiny Neovim plugin to highlight text matching the current selection in visual mode 💫
# Date de création: 2025-01-11T22:50:40Z
# Topics: neovim, neovim-plugin, nvim, nvim-plugin
# --------------------------------------------------
# Nom du dépôt: music_llm
# URL du dépôt: https://github.com/qiuqiangkong/music_llm
# Description: Pas de description disponible
# Date de création: 2025-01-15T06:50:56Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: arichain
# URL du dépôt: https://github.com/Zlkcyber/arichain
# Description: auto register/reff for arichain
# Date de création: 2025-01-19T12:51:55Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: agentin
# URL du dépôt: https://github.com/agentin-ai/agentin
# Description: AI Agents for Technology Services
# Date de création: 2025-01-10T18:51:03Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: audiobookbay-automated
# URL du dépôt: https://github.com/JamesRy96/audiobookbay-automated
# Description: Adds torrents from AudioBookBay to a torrent client and set the download location.
# Date de création: 2025-01-10T22:36:46Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: FluxPanel
# URL du dépôt: https://github.com/Richard0403/FluxPanel
# Description: FluxPanel基于FastApi+SqlAlchemy+Vue3开发的管理系统，易于拓展，支持代码一键生成
# Date de création: 2025-01-20T03:25:02Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: PPL-0day
# URL du dépôt: https://github.com/pulpocaminante/PPL-0day
# Description: Demoting PPL anti-malware services to less than a guest user
# Date de création: 2025-01-29T02:21:45Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: HackStarter-Kit
# URL du dépôt: https://github.com/veroleone/HackStarter-Kit
# Description: The HackStarter Kit is a collection of tools, guides, and insights to help beginners explore cybersecurity. It covers WiFi deauthentication, BLE manipulation, RF analysis, and more, while helping avoid common mistakes.
# Date de création: 2025-01-08T12:13:38Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: speedtest-ex
# URL du dépôt: https://github.com/WJQSERVER/speedtest-ex
# Description: 基于Go Gin的高效Speedtest
# Date de création: 2025-01-04T08:51:33Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: ConfigurableKit
# URL du dépôt: https://github.com/Lakr233/ConfigurableKit
# Description: Set up settings pages like a charm with UIKit.
# Date de création: 2025-01-04T21:31:23Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: CoT-Lab-Demo
# URL du dépôt: https://github.com/Intelligent-Internet/CoT-Lab-Demo
# Description: Pas de description disponible
# Date de création: 2025-01-30T01:22:00Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: game-python
# URL du dépôt: https://github.com/game-by-virtuals/game-python
# Description: Pas de description disponible
# Date de création: 2025-01-09T08:56:25Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: monads.ai
# URL du dépôt: https://github.com/neurons-me/monads.ai
# Description: Client-Side Component of Hybrid Cloud-Peer-to-Peer Artificial Intelligence.
# Date de création: 2025-01-17T18:14:12Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Aries
# URL du dépôt: https://github.com/LAMDASZ-ML/Aries
# Description: ARIES (ArXiv Research Intelligent Efficient Summary)
# Date de création: 2025-01-05T10:18:48Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: com.genmanai
# URL du dépôt: https://github.com/MetastartTech/com.genmanai
# Description: GenManAI is an open-source platform designed to streamline and revolutionize prompt testing for generative AI models.
# Date de création: 2025-01-21T04:48:30Z
# Topics: ai-development, ai-tools, developer-tools, expressjs, generative-ai, nextjs, open-source, prompt-engineering, typescript
# --------------------------------------------------
# Nom du dépôt: localllm
# URL du dépôt: https://github.com/qusaismael/localllm
# Description: Your LLM, Your Data , Your GUI.
# Date de création: 2025-01-26T22:44:22Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: BO3Enhanced
# URL du dépôt: https://github.com/shiversoftdev/BO3Enhanced
# Description: BO3Enhanced is a modification to the Windows Store edition of Black Ops 3 that lets you use Steam game files and play with other steam players.
# Date de création: 2025-01-25T14:27:06Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: findmy-traccar-bridge
# URL du dépôt: https://github.com/jannisko/findmy-traccar-bridge
# Description: A simple script to continuously import OpenHaystack locations into Traccar
# Date de création: 2025-01-16T19:45:00Z
# Topics: findmy, gps, openhaystack, python, traccar
# --------------------------------------------------
# Nom du dépôt: distillKitPlus
# URL du dépôt: https://github.com/agokrani/distillKitPlus
# Description: Easy to use, High Performant Knowledge Distillation for LLMs
# Date de création: 2025-01-06T09:48:40Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: sc2kfix
# URL du dépôt: https://github.com/araxestroy/sc2kfix
# Description: Bugfix DLL for SimCity 2000 Special Edition (1996)
# Date de création: 2025-01-17T08:04:10Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: llm-scraper-worker
# URL du dépôt: https://github.com/threepointone/llm-scraper-worker
# Description: Pas de description disponible
# Date de création: 2025-01-07T14:11:01Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: binary.nvim
# URL du dépôt: https://github.com/jackplus-xyz/binary.nvim
# Description: A minmal Neovim colorscheme using only two colors for a plain text editor experience.
# Date de création: 2025-01-08T20:14:33Z
# Topics: neovim-colorscheme, neovim-plugin
# --------------------------------------------------
# Nom du dépôt: flycheck-overlay
# URL du dépôt: https://github.com/konrad1977/flycheck-overlay
# Description: A beautiful inline flycheck overlay for Emacs
# Date de création: 2025-01-25T11:06:14Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: smooth-scrolling
# URL du dépôt: https://github.com/iHelops/smooth-scrolling
# Description: Improves scrolling performance in Spotify
# Date de création: 2025-01-21T10:08:35Z
# Topics: spicetify-extensions
# --------------------------------------------------
# Nom du dépôt: GeoPixel
# URL du dépôt: https://github.com/mbzuai-oryx/GeoPixel
# Description: GeoPixel: A Pixel Grounding Large Multimodal Model for Remote Sensing is specifically developed for high-resolution remote sensing image analysis, offering advanced multi-target pixel grounding capabilities.
# Date de création: 2025-01-23T11:02:46Z
# Topics: foundation-models, grounding-llms, large-multimodal-models, large-vision-language-models, remote-sensing, segmentation-models, vision-language-models
# --------------------------------------------------
# Nom du dépôt: BEN2_ComfyUI
# URL du dépôt: https://github.com/PramaLLC/BEN2_ComfyUI
# Description: Pas de description disponible
# Date de création: 2025-01-30T19:27:53Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: SUCTF-2025
# URL du dépôt: https://github.com/team-su/SUCTF-2025
# Description: Official Writeup of SUCTF 2025
# Date de création: 2025-01-13T14:14:18Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: pkg-stats
# URL du dépôt: https://github.com/mdjastrzebski/pkg-stats
# Description: Beautiful package download stats
# Date de création: 2025-01-09T18:49:05Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Latex_for_review_comments
# URL du dépôt: https://github.com/NeuroDong/Latex_for_review_comments
# Description: Pas de description disponible
# Date de création: 2025-01-15T09:36:57Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: expo-open-ota
# URL du dépôt: https://github.com/axelmarciano/expo-open-ota
# Description: An open-source self-hosted custom updates server implementing the Expo Updates protocol, built for production. Supports cloud storage & CDN.
# Date de création: 2025-01-22T16:16:56Z
# Topics: eas, eas-updates, eoas, expo, expo-custom-updates-server, expo-open-ota, expo-updates, expo-updates-server, go, golang, react-native
# --------------------------------------------------
# Nom du dépôt: taitan-orm
# URL du dépôt: https://github.com/thegenius/taitan-orm
# Description: The State of Art ORM for Rust
# Date de création: 2025-01-01T03:39:24Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: loadforecast
# URL du dépôt: https://github.com/wenlongliaoEE/loadforecast
# Description: Pas de description disponible
# Date de création: 2025-01-24T15:56:43Z
# Topics: Aucun topic
# --------------------------------------------------
# Nom du dépôt: Action-KernelSU-Next
# URL du dépôt: https://github.com/Laomaoi/Action-KernelSU-Next
# Description: 使用Github Action自动编译一加KernelSU Next内核
# Date de création: 2025-01-08T07:21:32Z
# Topics: Aucun topic
# --------------------------------------------------
